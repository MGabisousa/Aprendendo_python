# %%
#maria gabriela de paiva sousa 
print("jogador 1 escolha uma palavra de 5 letras.")
palavra=input("sua palavra é:")
print("-"*130)

print("jogador_2 você tem 6 tentativas para adivinhar a palavra de 5 letras do jogador_1") 
print("-"*130) 

t1=input("tentativa_1:")
a=set(list(t1))
b=set(list(palavra))
c=a-b
print("Não esta na palavra" , c)
print("esta na palavra", set(b) & set(a))
print("esta na palavra na posição certa")
if palavra[0]== t1[0]:
    print(palavra[0])
if palavra[1] == t1[1]:
    print(palavra[1])
if palavra[2]== t1[2]:
    print(palavra[2])
if palavra[3]== t1[3]:
    print(palavra[3])
if palavra[4]== t1[4]:
    print(palavra[4])
if palavra == t1:
    print("parabéns você acetou!!!!!!!")
else:
    print("não é essa palavra ,você ainda tem 5 tentativas" )
print("-"*130)

t2=input("tentativa_2:")
d=set(list(t2))
e=set(list(palavra))
f=d-e
print("Não esta na palavra" , f,c)
print("esta na palavra", set(d) & set(e))
print("esta na palavra na posição certa")
if palavra[0]== t2[0]:
    print(palavra[0])
if palavra[1]== t2[1]:
    print(palavra[1])
if palavra[2]== t2[2]:
    print(palavra[2])
if palavra[3]== t2[3]:
    print(palavra[3])
if palavra[4]== t2[4]:
    print(palavra[4])
if palavra == t2:
    print("parabéns você acetou!!!!!!!")
else:
    print("não é essa palavra ,você ainda tem 4 tentativas" )
print("-"*130) 
    
t3=input("tentativa_3:")
g=set(list(t3))
h=set(list(palavra))
i=g-h
print("Não esta na palavra" ,i,f,c)
print("esta na palavra", set(g) & set(h))
print("esta na palavra na posição certa")
if palavra[0]== t3[0]:
    print(palavra[0])
if palavra[1]== t3[1]:
    print(palavra[1])
if palavra[2]== t3[2]:
    print(palavra[2])
if palavra[3]== t3[3]:
    print(palavra[3])
if palavra[4]== t3[4]:
    print(palavra[4])
if palavra == t3:
    print("parabéns você acetou!!!!!!!")
else:
    print("não é essa palavra ,você ainda tem 3 tentativas" )
print("-"*130)   
    
t4=input("tentativa_4:")
j=set(list(t4))
k=set(list(palavra))
l=j-k
print("Não esta na palavra" ,c,f,i,l)
print("esta na palavra", set(j) & set(k))
print("esta na palavra na posição certa")
if palavra[0]== t4[0]:
    print(palavra[0])
if palavra[1]== t4[1]:
    print(palavra[1])
if palavra[2]== t4[2]:
    print(palavra[2])
if palavra[3]== t4[3]:
    print(palavra[3])
if palavra[4]== t4[4]:
    print(palavra[4])
if palavra == t4:
    print("parabéns você acetou!!!!!!!")
else:
    print("não é essa  palavra ,você ainda tem 2 tentativas" )
print("-"*130)   
    
t5=input("tentativa_5:")
m=set(list(t5))
n=set(list(palavra))
o=m-n
print("Não esta na palavra" , c,f,i,l,o)
print("esta na palavra",set(m) & set(n))
print("esta na palavra na posição certa")
if palavra[0]== t5[0]:
    print(palavra[0])
if palavra[1]== t5[1]:
    print(palavra[1])
if palavra[2]== t5[2]:
    print(palavra[2])
if palavra[3]== t5[3]:
    print(palavra[3])
if palavra[4]== t5[4]:
    print(palavra[4])
if palavra == t5:
    print("parabéns você acetou!!!!!!!")
else:
    print("não é essa palavra ,você ainda tem 1 tentativas" )
print("-"*130) 
   
t6=input("tentativa_6:")
o=set(list(t6))
p=set(list(palavra))
q=o-p
print("Não esta na palavra" ,  c,f,i,l,o,q)
print("esta na palavra", set(o) & set(p))
print("esta na palavra na posição certa")
if palavra[0]== t6[0]:
    print(palavra[0])
if palavra[1]== t6[1]:
    print(palavra[1])
if palavra[2]== t6[2]:
    print(palavra[2])
if palavra[3]== t6[3]:
    print(palavra[3])
if palavra[4]== t6[4]:
    print(palavra[4])

if palavra == t6:
    print("parabéns você acetou!!!!!!!")
else:
    print("não é essa palavra, você perdeu ,a palavra era: ", palavra )
print("-"*130)
